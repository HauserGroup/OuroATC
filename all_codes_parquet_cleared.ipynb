# %%
import pyspark
import dxpy
import dxdata

# %%
sc = pyspark.SparkContext()
spark = pyspark.sql.SparkSession(sc)

# %%
dispensed_database_name = dxpy.find_one_data_object(classname="database", name="app*", folder="/", name_mode="glob", describe=True)["describe"]["name"]
dispensed_dataset_id = dxpy.find_one_data_object(typename="Dataset", name="app*.dataset", folder="/", name_mode="glob")["id"]

# %%
scripts = dxdata.load_dataset(id=dispensed_dataset_id)["gp_scripts"]
# scripts = dataset["gp_scripts"]
field_names = [f.name for f in scripts.fields]
df = scripts.retrieve_fields(names=field_names, engine=dxdata.connect())
# df.show(truncate=False)
print('cleared')
# Out:
# cleared

# %%
df = df.dropDuplicates(["read_2", "bnf_code", "dmd_code", "drug_name", "quantity"]).drop("eid", "data_provider", "issue_date")

# %%
df = df.select('*', df.bnf_code.isNotNull().alias("has_bnf"), df.read_2.isNotNull().alias("has_read_2"), df.dmd_code.isNotNull().alias("has_dmd"))

# %%
df.count()
# Out:
# 727778

# %%
df.show(truncate=False)
# Out:
# +-------+---------------+------------------+--------------------------------------------------------------------------------------------+----------------------+-------+----------+-------+
# |read_2 |bnf_code       |dmd_code          |drug_name                                                                                   |quantity              |has_bnf|has_read_2|has_dmd|
# +-------+---------------+------------------+--------------------------------------------------------------------------------------------+----------------------+-------+----------+-------+
# |null   |0402010ABAAACAC|null              |Quetiapine Fumarate  Tablets  100 mg                                                        |28.000                |true   |false     |false  |
# |null   |01.03.05.00.00 |null              |Omeprazole 10mg gastro-resistant capsules                                                   |56 capsule            |true   |false     |false  |
# |null   |13.04.02.00.00 |null              |Clobetasone 0.05% cream                                                                     |30 gram - 0.05 %      |true   |false     |false  |
# |bs18.  |null           |null              |null                                                                                        |null                  |false  |true      |false  |
# |null   |03.01.02.00.00 |null              |Tiotropium bromide 2.5micrograms/dose solution for inhalation cartridge with device CFC free|2 inhaler             |true   |false     |false  |
# |null   |01.09.01.00.00 |null              |Ursodeoxycholic acid 150mg tablets                                                          |4*60 tablets - 150 mg |true   |false     |false  |
# |null   |05.01.01.03.00 |null              |Amoxicillin 500mg capsules                                                                  |21 capsule(s) - 500 mg|true   |false     |false  |
# |bu51.  |null           |null              |null                                                                                        |null                  |false  |true      |false  |
# |null   |02.04.00.00.00 |null              |Bisoprolol 5mg tablets                                                                      |84 tablets            |true   |false     |false  |
# |null   |04.03.01.00.00 |null              |Doxepin 25mg capsules                                                                       |28 capsule            |true   |false     |false  |
# |bxky.  |02120400       |null              |Rosuvastatin 20mg tablets                                                                   |56.000                |true   |true      |false  |
# |a6b1.  |null           |null              |null                                                                                        |null                  |false  |true      |false  |
# |null   |04.03.03.00.00 |null              |Fluoxetine 20mg capsules                                                                    |30 capsule(s)         |true   |false     |false  |
# |null   |02.09.03.00.00 |null              |Asasantin Retard capsules (Boehringer Ingelheim Ltd)                                        |60 capsules           |true   |false     |false  |
# |m45Z.00|null           |103495001000027101|CLOTRIMAZOLE + HYDROCORTISONE crm 1% + 1%                                                   |60.000                |false  |true      |true   |
# |null   |03.01.01.03.00 |null              |Ventolin 100micrograms/dose Evohaler (GlaxoSmithKline UK Ltd)                               |2 - 200 dose inhaler  |true   |false     |false  |
# |null   |02.06.02.00.00 |null              |Nifedipine 20mg modified-release tablets                                                    |56 tablet(s)          |true   |false     |false  |
# |null   |02.05.05.01.00 |null              |Ramipril 2.5mg capsules                                                                     |28 capsule            |true   |false     |false  |
# |null   |04.07.02.00.00 |null              |Co-codamol 8mg/500mg effervescent tablets                                                   |100 tab               |true   |false     |false  |
# |a6c2.  |null           |null              |null                                                                                        |null                  |false  |true      |false  |
# +-------+---------------+------------------+--------------------------------------------------------------------------------------------+----------------------+-------+----------+-------+
# only showing top 20 rows

# %%
df.write.partitionBy("has_bnf","has_read_2", "has_dmd").parquet('/tmp/all_codes.parquet')

# %%
# !hadoop fs -get /tmp/all_codes.parquet
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/cluster/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.10.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/cluster/dnax/jars/dnanexus-api-0.1.0-SNAPSHOT-jar-with-dependencies.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 23/01/19 12:21:31 WARN metrics.MetricsReporter: Unable to initialize metrics scraping configurations from hive-site.xml. Message:InputStream cannot be null
# 23/01/19 12:21:31 WARN service.DNAxApiSvc: Using default configurations. Unable to find dnanexus.conf.location=null
# 23/01/19 12:21:31 INFO service.DNAxApiSvc: apiserver connection-pool config. MaxPoolSize=10, MaxPoolPerRoute=10,MaxWaitTimeout=60000
# 23/01/19 12:21:31 INFO service.DNAxApiSvc: initializing http connection manager pools
# 23/01/19 12:21:31 INFO service.DNAxApiSvc: Worker process - IdleConnectionMonitorThread disabled
# 23/01/19 12:21:31 INFO service.DNAxApiSvc: Worker process - IdleConnectionMonitorThread disabled
# 23/01/19 12:21:31 INFO service.DNAxApiSvc: initializing DNAxApiSvc
# 23/01/19 12:21:32 WARN service.DNAxApiSvc: Shutting down Runtime service for Connection Pools
# 23/01/19 12:21:32 INFO service.DNAxApiSvc: shutting down httpClientConnManager
# 23/01/19 12:21:32 INFO service.DNAxApiSvc: shutting down httpsClientConnManager

# %%
# !du -sh all_codes.parquet
# Out:
# 13M	all_codes.parquet

# %%
# !dx upload -r --path /Prescriptions/ all_codes.parquet

# %%
# Remove EID
# Requires polars
import polars as pl

# %%
df = pl.scan_parquet("/mnt/project/Prescriptions/all_codes.parquet/*/*/*/*.snappy.parquet")

# %%
df.filter(pl.col('read_2').is_null() & pl.col('bnf_code').is_null() & pl.col('dmd_code').is_null()).select(pl.col('drug_name').unique()).collect()
# Out:
# shape: (1348, 1)
# ┌─────────────────────────────────────┐
# │ drug_name                           │
# │ ---                                 │
# │ str                                 │
# ╞═════════════════════════════════════╡
# │ ACTIVE GLUCOSE STRIPS TEST STRIP... │
# │ GLUCOTREND PLUS REAGENT STRIP       │
# │ Triptorelin  Powder and solvent ... │
# │ Biatain Non-Adhesive  Dressing  ... │
# │ ...                                 │
# │ Vismed  Eye Drops Unit Dose  Pre... │
# │ Comfifast Easy Wrap  Vest Long S... │
# │ Penfine  Needles for insulin pen... │
# │ Polymem  Dressing (With Adhesive... │
# └─────────────────────────────────────┘

# %%
df.columns
# Out:
# ['read_2', 'bnf_code', 'dmd_code', 'drug_name', 'quantity']
